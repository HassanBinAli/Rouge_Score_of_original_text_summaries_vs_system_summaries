# %%
# !pip install bert-extractive-summarizer
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 12.5 MB/s
# ...
#      |████████████████████████████████| 636 kB 36.2 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 25.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 22.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install rouge

# %%
from summarizer import Summarizer, TransformerSummarizer
import pandas as pd
from rouge import Rouge

# %%
rouge = Rouge()
GPT2_model = TransformerSummarizer(transformer_type='GPT2', transformer_model_key='gpt2-large')
# Out:
# Downloading:   0%|          | 0.00/764 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
data = []
for i in range(1,68):
  f = open('/content/drive/MyDrive/DataSet/caseno'+str(i)+'.txt', 'r')
  body = f.read()
  system_summary = ''.join(GPT2_model(body, min_length=60))
  f = open('/content/drive/MyDrive/DataSet/caseno'+str(i)+'_summary.txt', 'r')
  reference_summary = f.read()
  rouge_score = rouge.get_scores(system_summary, reference_summary)
  l1 = list(rouge_score[0].get("rouge-1").values())
  l2 = list(rouge_score[0].get("rouge-2").values())
  l3 = list(rouge_score[0].get("rouge-l").values())
  l0 = ["caseno"+str(i)+".txt"]
  data.append(l0+l1+l2+l3)
  print(i, "done")
# Out:
# 1 done
# 2 done
# 3 done
# 4 done
# 5 done
# 6 done
# 7 done
# 8 done
# 9 done
# 10 done
# 11 done
# 12 done
# 13 done
# 14 done
# 15 done
# 16 done
# 17 done
# 18 done
# 19 done
# 20 done
# 21 done
# 22 done
# 23 done
# 24 done
# 25 done
# 26 done
# 27 done
# 28 done
# 29 done
# 30 done
# 31 done
# 32 done
# 33 done
# 34 done
# 35 done
# 36 done
# 37 done
# 38 done
# 39 done
# 40 done
# 41 done
# 42 done
# 43 done
# 44 done
# 45 done
# 46 done
# 47 done
# 48 done
# 49 done
# 50 done
# 51 done
# 52 done
# 53 done
# 54 done
# 55 done
# 56 done
# 57 done
# 58 done
# 59 done
# 60 done
# 61 done
# 62 done
# 63 done
# 64 done
# 65 done
# 66 done
# 67 done

# %%
df = pd.DataFrame(data, columns=["file_name", "Rouge-1(F1)", "Rouge-1(P)", "Rouge-1(R)", "Rouge-2(F1)", "Rouge-2(P)", "Rouge-2(R)", "Rouge-L(F1)", "Rouge-L(P)", "Rouge-L(R)"])

# %%
df.describe()
# Out:
#        Rouge-1(F1)  Rouge-1(P)  Rouge-1(R)  ...  Rouge-L(F1)  Rouge-L(P)  Rouge-L(R)
# count    67.000000   67.000000   67.000000  ...    67.000000   67.000000   67.000000
# mean      0.339472    0.448885    0.373704  ...     0.312131    0.413101    0.343678
# std       0.074775    0.115356    0.061270  ...     0.072000    0.112289    0.061389
# min       0.138329    0.169734    0.218421  ...     0.135447    0.155419    0.200000
# 25%       0.293178    0.355823    0.338228  ...     0.266299    0.332391    0.315798
# 50%       0.341772    0.441948    0.374840  ...     0.317365    0.397959    0.345679
# 75%       0.380066    0.543697    0.413499  ...     0.346192    0.493304    0.386098
# max       0.511905    0.677966    0.520661  ...     0.497024    0.677966    0.483471
#
# [8 rows x 9 columns]

# %%
#df.to_csv("/content/drive/MyDrive/Rouge_scores_for_GPT2(large).csv", index=False)
